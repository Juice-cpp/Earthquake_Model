# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Higienização

# %%
import pandas as pd

# Carregar o dataset
# Certifique-se de que o arquivo 'earthquakes.csv' fez o upload no Colab
df = pd.read_csv('Dataset/earthquakes.csv')

# Exibir as primeiras linhas originais e o tamanho do dataset
print(f"Tamanho original do dataset: {df.shape}")
display(df.head())
# Out:
# Tamanho original do dataset: (1137, 43)
#            id  magnitude        type  \
# 0  us7000necw        4.8  earthquake
# 1  tx2024shcj        5.1  earthquake
# 2  ci40734823        3.7  earthquake
# 3  tx2024scvz        3.9  earthquake
# 4  us7000ndte        4.1  earthquake
#
#                                         title                 date  \
# 0         M 4.8 - 33 km WSW of Ackerly, Texas  2024-09-17T00:49:42
# 1         M 5.1 - 34 km WSW of Ackerly, Texas  2024-09-17T00:49:42
# 2                M 3.7 - 6 km N of Malibu, CA  2024-09-16T11:22:08
# 3  M 3.9 - 58 km S of Whites City, New Mexico  2024-09-14T17:01:06
# 4  M 4.1 - 60 km S of Whites City, New Mexico  2024-09-14T17:01:06
#
#             time        updated  \
# 0  1726534182289  1726583895255
# 1  1726534182183  1726672002991
# 2  1726485728190  1726637414586
# 3  1726333266539  1726584426218
# 4  1726333266382  1726334616179
#
#                                                  url  \
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                            detailUrl  felt  ...  \
# 0  https://earthquake.usgs.gov/earthquakes/feed/v...  1893  ...
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...  2042  ...
# 2  https://earthquake.usgs.gov/fdsnws/event/1/que...  1580  ...
# 3  https://earthquake.usgs.gov/fdsnws/event/1/que...     5  ...
# 4  https://earthquake.usgs.gov/earthquakes/feed/v...     4  ...
#
#                   location      continent                         country  \
# 0           Ackerly, Texas  North America  United States of America (the)
# 1           Ackerly, Texas  North America  United States of America (the)
# 2               Malibu, CA  North America  United States of America (the)
# 3  Whites City, New Mexico  North America  United States of America (the)
# 4  Whites City, New Mexico  North America  United States of America (the)
#
#   subnational            city             locality postcode  \
# 0       Texas  Tarzan-Lenorah       Tarzan-Lenorah  79783.0
# 1       Texas  Tarzan-Lenorah       Tarzan-Lenorah  79331.0
# 2  California     Los Angeles  Agoura Hills-Malibu  90265.0
# 3       Texas        Van Horn             Van Horn      NaN
# 4       Texas        Van Horn             Van Horn      NaN
#
#                    what3words timezone  \
# 0    landmass.perkily.affords     -300
# 1    escalator.grownups.dwell     -300
# 2    clocking.uploaded.issuer     -420
# 3     sailboats.sawn.speeding     -300
# 4  spinners.downtime.computes     -300
#
#                                      locationDetails
# 0  [{'id': '80684', 'wikidataId': '', 'name': '79...
# 1  [{'id': '89341', 'wikidataId': '', 'name': '48...
# 2  [{'id': '93478', 'wikidataId': 'Q844837', 'nam...
# 3  [{'id': '9', 'wikidataId': 'Q49', 'name': 'Nor...
# 4  [{'id': '9', 'wikidataId': 'Q49', 'name': 'Nor...
#
# [5 rows x 43 columns]

# %%
# Lista de colunas para remover baseada na análise prévia
colunas_para_remover = [
    'id', 'code', 'url', 'detailUrl', 'what3words', 'ids', # Identificadores e Links
    'type', 'geometryType',                                # Valores constantes
    'updated', 'time',                                     # Metadados de sistema/timestamps duplicados
    'title', 'locationDetails', 'place', 'placeOnly',      # Textos redundantes ou complexos
    'location', 'city', 'locality',                        # Textos geográficos propensos a erros
    'postcode'                                             # Excesso de dados nulos
]

# Removendo as colunas
df_clean = df.drop(columns=colunas_para_remover)

print(f"Tamanho após remoção de colunas: {df_clean.shape}")
# Out:
# Tamanho após remoção de colunas: (1137, 25)

# %%
# Verificando a quantidade de nulos antes do tratamento
print("Valores nulos antes do tratamento:")
print(df_clean.isnull().sum()[df_clean.isnull().sum() > 0])

# Preenchendo valores nulos em colunas categóricas com 'Unknown'
colunas_categoricas_com_nulos = ['alert', 'continent', 'country', 'subnational']
for col in colunas_categoricas_com_nulos:
    if col in df_clean.columns:
        df_clean[col] = df_clean[col].fillna('Unknown')

# Se houver alguma outra linha que ainda tenha nulos (dados corrompidos), nós a removemos
df_clean = df_clean.dropna()

print("\nValores nulos após o tratamento:")
print(df_clean.isnull().sum().max()) # Deve retornar 0
print(f"Tamanho após tratamento de nulos: {df_clean.shape}")
# Out:
# Valores nulos antes do tratamento:
# alert          373
# continent      270
# country        338
# subnational    421
# dtype: int64
#
# Valores nulos após o tratamento:
# 0
# Tamanho após tratamento de nulos: (1137, 25)

# %%
# Converter a coluna 'date' para o formato datetime
df_clean['date'] = pd.to_datetime(df_clean['date'])

# (Opcional) Extrair ano, mês e hora para ajudar modelos de Machine Learning
df_clean['year'] = df_clean['date'].dt.year
df_clean['month'] = df_clean['date'].dt.month
df_clean['day'] = df_clean['date'].dt.day
#df_clean['hour'] = df_clean['date'].dt.hour

# Exibir os tipos de dados atualizados
print(df_clean.dtypes)
# Out:
# magnitude             float64
# date           datetime64[us]
# felt                    int64
# cdi                     int64
# mmi                     int64
# alert                     str
# status                    str
# tsunami                 int64
# sig                     int64
# net                       str
# sources                   str
# types                     str
# nst                     int64
# dmin                  float64
# rms                   float64
# gap                   float64
# magType                   str
# depth                 float64
# latitude              float64
# longitude             float64
# distanceKM              int64
# continent                 str
# country                   str
# subnational               str
# timezone                int64
# year                    int32
# month                   int32
# day                     int32
# dtype: object

# %% [markdown]
# # Geopy

# %%
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import pandas as pd
import time

# %%
from geopy.geocoders import Nominatim
import time

# Inicializar a API
geolocator = Nominatim(user_agent="meu_projeto_terremotos_ia")

# 1. Identificar quais linhas estão com o país "Unknown" (ou nulo)
# Assumindo que você usou o código anterior e preencheu os nulos com 'Unknown'
filtro_sem_pais = df_clean['country'] == 'Unknown'

# Mostrar quantos países faltam
quantidade_faltante = filtro_sem_pais.sum()
print(f"Buscando o país exato para {quantidade_faltante} registros...")

# 2. Criar a função otimizada para a API
def atualizar_pais_faltante(linha):
    coord = f"{linha['latitude']}, {linha['longitude']}"
    try:
        time.sleep(1) # Pausa obrigatória de 1 segundo
        loc = geolocator.reverse(coord, language='en', timeout=10)

        # Se encontrou um local com endereço e país
        if loc and 'address' in loc.raw and 'country' in loc.raw['address']:
            return loc.raw['address']['country']

        # Se a API funcionou, mas não retornou país, é porque está no oceano!
        return 'Ocean/Offshore'

    except Exception as e:
        # Se der erro na conexão, mantém como Unknown para tentarmos depois
        return 'Unknown'

# 3. Aplicar a função APENAS nas linhas filtradas
# Usamos o .loc para atualizar o df_clean original diretamente na coluna 'country'
if quantidade_faltante > 0:
    df_clean.loc[filtro_sem_pais, 'country'] = df_clean[filtro_sem_pais].apply(atualizar_pais_faltante, axis=1)

print("\nBusca concluída! Veja como ficou a distribuição dos países agora:")
# 4. Verificar o resultado final (quais países a IA agora conhece)
print(df_clean['country'].value_counts().head(10))
# Out:
# Buscando o país exato para 338 registros...
#
# Busca concluída! Veja como ficou a distribuição dos países agora:
# country
# United States of America (the)    423
# Ocean/Offshore                    335
# Japan                              68
# Taiwan (Province of China)         55
# Indonesia                          38
# China                              30
# Chile                              29
# Afghanistan                        26
# Argentina                          26
# Philippines (the)                  17
# Name: count, dtype: int64

# %%
import pandas as pd

# 1. Obter as contagens do DataFrame original (df) e do limpo (df_clean)
# Usamos dropna=False no df original para ele contar os nulos também!
contagem_antes = df['country'].value_counts(dropna=False)
contagem_depois = df_clean['country'].value_counts()

# 2. Criar um novo DataFrame que junta as duas contagens lado a lado
df_comparacao = pd.DataFrame({
    'Antes': contagem_antes,
    'Depois': contagem_depois
})

# 3. Tratar os buracos (países que existem em um mas não no outro)
# fillna(0) troca os vazios por zero, e astype(int) deixa os números inteiros
df_comparacao = df_comparacao.fillna(0).astype(int)

# 4. Criar a coluna da sua lógica matemática (A Diferença)
df_comparacao['Diferença'] = df_comparacao['Depois'] - df_comparacao['Antes']

# 5. Exibir o resultado, ordenando pelas categorias que mais mudaram
display(df_comparacao.sort_values(by='Diferença', ascending=False))
# Out:
#                                         Antes  Depois  Diferença
# country
# Ocean/Offshore                              0     335        335
# Greece                                      0       3          3
# Argentina                                  26      26          0
# Afghanistan                                26      26          0
# Brazil                                      2       2          0
# Bangladesh                                  2       2          0
# Chile                                      29      29          0
# China                                      30      30          0
# Congo (the Democratic Republic of the)      1       1          0
# Bolivia (Plurinational State of)            5       5          0
# Djibouti                                    1       1          0
# Ecuador                                     1       1          0
# El Salvador                                 1       1          0
# Guatemala                                   1       1          0
# India                                       3       3          0
# Indonesia                                  38      38          0
# Iran (Islamic Republic of)                 11      11          0
# Canada                                      8       8          0
# Japan                                      68      68          0
# Mexico                                     11      11          0
# Myanmar                                     3       3          0
# Montenegro                                  4       4          0
# Nepal                                       6       6          0
# New Zealand                                 3       3          0
# Nicaragua                                   1       1          0
# Pakistan                                    3       3          0
# Peru                                       11      11          0
# Philippines (the)                          17      17          0
# Taiwan (Province of China)                 55      55          0
# Tanzania, the United Republic of            1       1          0
# Turkiye                                     7       7          0
# United States of America (the)            423     423          0
# Viet Nam                                    1       1          0
# NaN                                       338       0       -338

# %%
# 1. Verificar quantas linhas estão exatamente duplicadas
quantidade_duplicados = df_clean.duplicated().sum()
print(f"Linhas duplicadas encontradas: {quantidade_duplicados}")

df_clean = df_clean.drop_duplicates()
# Out:
# Linhas duplicadas encontradas: 535

# %%
quantidade_duplicados = df_clean.duplicated().sum()
print(f"Linhas duplicadas encontradas: {quantidade_duplicados}")
# Out:
# Linhas duplicadas encontradas: 0

# %%
# Visualizar o dataset higienizado
display(df_clean.head())

# Salvar o novo dataset limpo
arquivo_limpo = 'Dataset/earthquakes_cleaned.csv'
df_clean.to_csv(arquivo_limpo, index=False)

print(f"\nHigienização concluída! O dataset limpo foi salvo como: {arquivo_limpo}")
# Out:
#    magnitude                date  felt  cdi  mmi    alert    status  tsunami  \
# 0        4.8 2024-09-17 00:49:42  1893    6    5    green  reviewed        0
# 1        5.1 2024-09-17 00:49:42  2042    6    5    green  reviewed        0
# 2        3.7 2024-09-16 11:22:08  1580    4    4  Unknown  reviewed        0
# 3        3.9 2024-09-14 17:01:06     5    3    4    green  reviewed        0
# 4        4.1 2024-09-14 17:01:06     4    3    4    green  reviewed        0
#
#     sig net  ... latitude longitude  distanceKM      continent  \
# 0   994  us  ...  32.3984  -102.044          33  North America
# 1  1040  tx  ...  32.4140  -102.057          34  North America
# 2   591  ci  ...  34.0678  -118.807           6  North America
# 3   236  tx  ...  31.6470  -104.450          58  North America
# 4   260  us  ...  31.6323  -104.473          60  North America
#
#                           country  subnational timezone  year  month  day
# 0  United States of America (the)        Texas     -300  2024      9   17
# 1  United States of America (the)        Texas     -300  2024      9   17
# 2  United States of America (the)   California     -420  2024      9   16
# 3  United States of America (the)        Texas     -300  2024      9   14
# 4  United States of America (the)        Texas     -300  2024      9   14
#
# [5 rows x 28 columns]
# Higienização concluída! O dataset limpo foi salvo como: Dataset/earthquakes_cleaned.csv

# %% [markdown]
# # F

# %%
# get correlation matrix
corr_matrx = df.corr(numeric_only=True)
plt.figure(figsize=(10,10))
# Applying Threshold bases mask
threshold = 0.4
mask = (corr_matrx < threshold) #and  (corr_matrx != 1)

# mask = np.triu(np.ones_like(df, dtype=bool)) # upper triangle mask

sns.heatmap(corr_matrx,annot=True,fmt='0.2f',cmap='coolwarm',mask=mask)
plt.show()


import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# 1. Obtendo a matriz de correlação
corr_matrx = df.corr(numeric_only=True)
plt.figure(figsize=(10, 10))

# 2. Criando as máscaras (filtros)
threshold = 0.4
mask_limiar = (corr_matrx < threshold) # Filtro para ocultar correlações fracas

# Cria uma matriz Verdadeiro/Falso onde APENAS a diagonal é Verdadeira
mask_diagonal = np.eye(len(corr_matrx), dtype=bool)

# 3. PLOT 1: Desenhando APENAS a diagonal principal
# Usamos '~mask_diagonal' para inverter e ocultar todo o resto do gráfico
# ListedColormap(['black']) define a cor exata da diagonal (pode mudar para 'gray', 'green', etc.)
sns.heatmap(corr_matrx,
            mask=~mask_diagonal,
            cmap=ListedColormap(['grey']),
            cbar=False,          # Remove a barra de cores lateral para não duplicar
            annot=True,
            fmt='0.2f')

# 4. PLOT 2: Desenhando o resto do gráfico por cima
# Juntamos as duas máscaras (ocultar menores que 0.4 OU a diagonal)
mask_final = mask_limiar | mask_diagonal

sns.heatmap(corr_matrx,
            mask=mask_final,
            cmap='coolwarm',
            annot=True,
            fmt='0.2f')

plt.show()

# %%
print(df.isnull().sum())
# Out:
# id                   0
# magnitude            0
# type                 0
# title                0
# date                 0
# time                 0
# updated              0
# url                  0
# detailUrl            0
# felt                 0
# cdi                  0
# mmi                  0
# alert              373
# status               0
# tsunami              0
# sig                  0
# net                  0
# code                 0
# ids                  0
# sources              0
# types                0
# nst                  0
# dmin                 0
# rms                  0
# gap                  0
# magType              0
# geometryType         0
# depth                0
# latitude             0
# longitude            0
# place                0
# distanceKM           0
# placeOnly            0
# location             0
# continent          270
# country            338
# subnational        421
# city               463
# locality             0
# postcode           940
# what3words           0
# timezone             0
# locationDetails      0
# dtype: int64

# %%
print(df_clean.isnull().sum())
# Out:
# magnitude      0
# date           0
# felt           0
# cdi            0
# mmi            0
# alert          0
# status         0
# tsunami        0
# sig            0
# net            0
# sources        0
# types          0
# nst            0
# dmin           0
# rms            0
# gap            0
# magType        0
# depth          0
# latitude       0
# longitude      0
# distanceKM     0
# continent      0
# country        0
# subnational    0
# timezone       0
# year           0
# month          0
# day            0
# dtype: int64

# %%
# 1. Verificar quantas linhas estão exatamente duplicadas
quantidade_duplicados = df.duplicated().sum()
print(f"Linhas duplicadas encontradas: {quantidade_duplicados}")

# 1. Verificar quantas linhas estão exatamente duplicadas
quantidade_duplicados = df_clean.duplicated().sum()
print(f"Linhas duplicadas encontradas: {quantidade_duplicados}")
# Out:
# Linhas duplicadas encontradas: 337
# Linhas duplicadas encontradas: 0

# %% [markdown]
# # Insights

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Configura o estilo dos gráficos
sns.set_theme(style="whitegrid")

# 1. Distribuição da Magnitude
plt.figure(figsize=(10, 5))
sns.histplot(df_clean['magnitude'], kde=True, color='red')
plt.title('Distribuição das Magnitudes dos Terremotos')
plt.show()

# %%
# 2. Relação entre Magnitude e Profundidade
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_clean, x='magnitude', y='depth', alpha=0.5, hue='tsunami')
plt.gca().invert_yaxis() # Profundidade geralmente é plotada invertida
plt.title('Magnitude vs Profundidade (com indicador de Tsunami)')
plt.show()

# %%
# 3. Top 10 Países com mais terremotos
plt.figure(figsize=(12, 6))
df_clean['country'].value_counts().head(10).plot(kind='bar', color='teal')
plt.title('Top 10 Países/Regiões com mais Registros')
plt.ylabel('Quantidade')
plt.xticks(rotation=45)
plt.show()

# %%
# 4. Boxplot para identificar Outliers de Magnitude
plt.figure(figsize=(8, 4))
sns.boxplot(x=df_clean['magnitude'], color='orange')
plt.title('Identificação de Outliers na Magnitude')
plt.show()

# %%
import plotly.express as px

fig = px.scatter_geo(df_clean,
                     lat='latitude',
                     lon='longitude',
                     color='magnitude',
                     hover_name='country',
                     size='magnitude',
                     title='Mapa de Terremotos (Tamanho e Cor por Magnitude)',
                     color_continuous_scale=px.colors.sequential.Plasma)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 11
#       1 import plotly.express as px
#       3 fig = px.scatter_geo(df_clean,
#       4                      lat='latitude',
#       5                      lon='longitude',
#    (...)      9                      title='Mapa de Terremotos (Tamanho e Cor por Magnitude)',
#      10                      color_continuous_scale=px.colors.sequential.Plasma)
# ---> 11 fig.show()
#
# File ~\PycharmProjects\Earthquake_Model\.venv\Lib\site-packages\plotly\basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)   3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File ~\PycharmProjects\Earthquake_Model\.venv\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %%
# Criar uma coluna temporária 'ano_mes' para facilitar a visualização
df_clean['ano_mes'] = df_clean['date'].dt.to_period('M')
contagem_tempo = df_clean.groupby('ano_mes').size()

plt.figure(figsize=(14, 6))
contagem_tempo.plot(kind='line', marker='o', color='b')
plt.title('Atividade Sísmica ao Longo do Tempo')
plt.xlabel('Ano e Mês')
plt.ylabel('Número de Terremotos')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
top_paises = df_clean['country'].value_counts().head(10)

sns.barplot(x=top_paises.values, y=top_paises.index, hue=top_paises.index, legend=False, palette='viridis')
plt.title('Top 10 Países com Mais Terremotos')
plt.xlabel('Quantidade de Terremotos')
plt.ylabel('País')
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.boxplot(ax=axes[0], x=df_clean['magnitude'], color='orange')
axes[0].set_title('Dispersão e Outliers da Magnitude')

sns.boxplot(ax=axes[1], x=df_clean['depth'], color='cyan')
axes[1].set_title('Dispersão e Outliers da Profundidade')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Relação entre Significância e Magnitude
sns.scatterplot(ax=axes[0], data=df_clean, x='magnitude', y='sig', hue='tsunami', alpha=0.7)
axes[0].set_title('Significância vs Magnitude (com indicador de Tsunami)')

# Contagem de Alertas de Tsunami
sns.countplot(ax=axes[1], data=df_clean, x='tsunami', hue='tsunami', legend=False, palette='Set2')
axes[1].set_title('Distribuição de Alertas de Tsunami (0 = Não, 1 = Sim)')

plt.tight_layout()
plt.show()

# %%
# 1. Verificar quantas linhas estão exatamente duplicadas
quantidade_duplicados = df.duplicated().sum()
print(f"Linhas duplicadas encontradas: {quantidade_duplicados}")

# 1. Verificar quantas linhas estão exatamente duplicadas
quantidade_duplicados = df_clean.duplicated().sum()
print(f"Linhas duplicadas encontradas: {quantidade_duplicados}")
# Out:
# Linhas duplicadas encontradas: 337
# Linhas duplicadas encontradas: 0

# %%
# Visualizar o dataset higienizado
display(df_clean.head())

# Salvar o novo dataset limpo
arquivo_limpo = 'Dataset/earthquakes_cleaned.csv'
df_clean.to_csv(arquivo_limpo, index=False)

print(f"\nHigienização concluída! O dataset limpo foi salvo como: {arquivo_limpo}")
# Out:
#    magnitude                date  felt  cdi  mmi    alert    status  tsunami  \
# 0        4.8 2024-09-17 00:49:42  1893    6    5    green  reviewed        0
# 1        5.1 2024-09-17 00:49:42  2042    6    5    green  reviewed        0
# 2        3.7 2024-09-16 11:22:08  1580    4    4  Unknown  reviewed        0
# 3        3.9 2024-09-14 17:01:06     5    3    4    green  reviewed        0
# 4        4.1 2024-09-14 17:01:06     4    3    4    green  reviewed        0
#
#     sig net  ... longitude distanceKM      continent  \
# 0   994  us  ...  -102.044         33  North America
# 1  1040  tx  ...  -102.057         34  North America
# 2   591  ci  ...  -118.807          6  North America
# 3   236  tx  ...  -104.450         58  North America
# 4   260  us  ...  -104.473         60  North America
#
#                           country  subnational  timezone  year  month  day  \
# 0  United States of America (the)        Texas      -300  2024      9   17
# 1  United States of America (the)        Texas      -300  2024      9   17
# 2  United States of America (the)   California      -420  2024      9   16
# 3  United States of America (the)        Texas      -300  2024      9   14
# 4  United States of America (the)        Texas      -300  2024      9   14
#
#    ano_mes
# 0  2024-09
# 1  2024-09
# 2  2024-09
# 3  2024-09
# 4  2024-09
#
# [5 rows x 29 columns]
# Higienização concluída! O dataset limpo foi salvo como: Dataset/earthquakes_cleaned.csv

# %%
new_df = pd.read_csv("Dataset/earthquakes_cleaned.csv")

# %%
new_df[["", ""]].head(30)
# Out:
#     magnitude                 date   felt  cdi  mmi    alert    status  \
# 0        4.80  2024-09-17 00:49:42   1893    6    5    green  reviewed
# 1        5.10  2024-09-17 00:49:42   2042    6    5    green  reviewed
# 2        3.70  2024-09-16 11:22:08   1580    4    4  Unknown  reviewed
# 3        3.90  2024-09-14 17:01:06      5    3    4    green  reviewed
# 4        4.10  2024-09-14 17:01:06      4    3    4    green  reviewed
# 5        3.23  2024-09-13 11:56:39    472    4    3  Unknown  reviewed
# 6        3.43  2024-09-12 16:37:32    234    4    3  Unknown  reviewed
# 7        3.44  2024-09-12 15:40:49    225    4    3  Unknown  reviewed
# 8        4.69  2024-09-12 14:28:21  18592    5    5    green  reviewed
# 9        3.50  2024-09-11 08:31:01      0    0    3  Unknown  reviewed
# 10       3.80  2024-09-10 18:03:00      5    3    4    green  reviewed
# 11       3.30  2024-09-09 09:50:37      1    3    4  Unknown  reviewed
# 12       3.80  2024-09-08 02:37:22      2    3    4  Unknown  reviewed
# 13       3.90  2024-09-08 02:37:22      1    3    4  Unknown  reviewed
# 14       3.35  2024-09-08 02:16:27     13    4    4  Unknown  reviewed
# 15       3.94  2024-09-07 17:34:20   2756    5    5  Unknown  reviewed
# 16       3.45  2024-09-07 17:05:45    824    4    4  Unknown  reviewed
# 17       3.09  2024-09-07 14:31:32      6    4    4  Unknown  reviewed
# 18       4.28  2024-09-07 14:30:36    241    5    5    green  reviewed
# 19       3.17  2024-09-07 06:03:42     11    3    2  Unknown  reviewed
# 20       3.47  2024-09-06 12:07:06     49    3    4  Unknown  reviewed
# 21       3.32  2024-09-05 20:04:29     27    3    3  Unknown  reviewed
# 22       3.10  2024-09-04 21:31:11      0    0    3  Unknown  reviewed
# 23       3.10  2024-09-04 21:31:10      0    0    3  Unknown  reviewed
# 24       3.00  2024-09-04 21:30:35      0    0    3  Unknown  reviewed
# 25       3.46  2024-09-03 12:11:58     11    3    3  Unknown  reviewed
# 26       3.14  2024-09-02 11:34:26      5    3    2  Unknown  reviewed
# 27       3.40  2024-09-01 11:01:44     71    3    4  Unknown  reviewed
# 28       3.50  2024-09-01 08:47:07      4    3    3  Unknown  reviewed
# 29       3.40  2024-08-31 10:01:04      0    0    4  Unknown  reviewed
#
#     tsunami   sig net  ... longitude distanceKM      continent  \
# 0         0   994  us  ...  -102.044         33  North America
# 1         0  1040  tx  ...  -102.057         34  North America
# 2         0   591  ci  ...  -118.807          6  North America
# 3         0   236  tx  ...  -104.450         58  North America
# 4         0   260  us  ...  -104.473         60  North America
# 5         0   340  ci  ...  -118.812          6  North America
# 6         0   277  ci  ...  -118.799          5  North America
# 7         0   272  ci  ...  -118.800          7  North America
# 8         1   818  ci  ...  -118.808          6  North America
# 9         0   188  nn  ...  -115.303          7  North America
# 10        0   224  tx  ...  -104.356         56  North America
# 11        0   168  tx  ...  -104.550         61  North America
# 12        0   223  tx  ...  -104.452         57  North America
# 13        0   234  us  ...  -104.466         61  North America
# 14        0   178  uu  ...  -112.420         15  North America
# 15        1   769  ci  ...  -117.586          4  North America
# 16        0   513  ci  ...  -117.593          5  North America
# 17        0   149  nc  ...  -122.734          3  North America
# 18        1   398  nc  ...  -122.746          1  North America
# 19        0   158  ci  ...  -118.599         22        Unknown
# 20        0   202  nc  ...  -119.598         18  North America
# 21        0   178  nc  ...  -120.167          8  North America
# 22        0   148  nn  ...  -117.142          8  North America
# 23        0   148  us  ...  -117.134          9  North America
# 24        0   138  us  ...  -117.067         16  North America
# 25        0   187  nc  ...  -118.758         14  North America
# 26        0   153  ci  ...  -118.628         21        Unknown
# 27        0   198  nc  ...  -118.469          7  North America
# 28        0   190  us  ...  -113.160         31  North America
# 29        0   178  tx  ...  -103.990         39  North America
#
#                            country  subnational  timezone  year  month  day  \
# 0   United States of America (the)        Texas      -300  2024      9   17
# 1   United States of America (the)        Texas      -300  2024      9   17
# 2   United States of America (the)   California      -420  2024      9   16
# 3   United States of America (the)        Texas      -300  2024      9   14
# 4   United States of America (the)        Texas      -300  2024      9   14
# 5   United States of America (the)   California      -420  2024      9   13
# 6   United States of America (the)   California      -420  2024      9   12
# 7   United States of America (the)   California      -420  2024      9   12
# 8   United States of America (the)   California      -420  2024      9   12
# 9   United States of America (the)       Nevada      -420  2024      9   11
# 10  United States of America (the)        Texas      -300  2024      9   10
# 11  United States of America (the)        Texas      -300  2024      9    9
# 12  United States of America (the)        Texas      -300  2024      9    8
# 13  United States of America (the)        Texas      -300  2024      9    8
# 14  United States of America (the)         Utah      -360  2024      9    8
# 15  United States of America (the)   California      -420  2024      9    7
# 16  United States of America (the)   California      -420  2024      9    7
# 17  United States of America (the)   California      -420  2024      9    7
# 18  United States of America (the)   California      -420  2024      9    7
# 19  United States of America (the)      Unknown      -420  2024      9    7
# 20  United States of America (the)   California      -420  2024      9    6
# 21  United States of America (the)   California      -420  2024      9    5
# 22  United States of America (the)       Nevada      -420  2024      9    4
# 23  United States of America (the)       Nevada      -420  2024      9    4
# 24  United States of America (the)       Nevada      -420  2024      9    4
# 25  United States of America (the)   California      -420  2024      9    3
# 26  United States of America (the)      Unknown      -420  2024      9    2
# 27  United States of America (the)   California      -420  2024      9    1
# 28  United States of America (the)      Montana      -360  2024      9    1
# 29  United States of America (the)        Texas      -300  2024      8   31
#
#     ano_mes
# 0   2024-09
# 1   2024-09
# 2   2024-09
# 3   2024-09
# 4   2024-09
# 5   2024-09
# 6   2024-09
# 7   2024-09
# 8   2024-09
# 9   2024-09
# 10  2024-09
# 11  2024-09
# 12  2024-09
# 13  2024-09
# 14  2024-09
# 15  2024-09
# 16  2024-09
# 17  2024-09
# 18  2024-09
# 19  2024-09
# 20  2024-09
# 21  2024-09
# 22  2024-09
# 23  2024-09
# 24  2024-09
# 25  2024-09
# 26  2024-09
# 27  2024-09
# 28  2024-09
# 29  2024-08
#
# [30 rows x 29 columns]
